# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Apple = yf.download("AAPL", start = "2010-01-01", end = "2021-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.487532
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.498751
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.395380
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.383556
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.425995
# ...                ...         ...         ...         ...         ...
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  129.850586
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  134.494781
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  132.703995
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  131.572464
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  130.559021
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# ...

# %%
ticker = ["SPY", "AAPL", "TSLA"]

# %%
stocks = yf.download(ticker, start = "2019-01-01", end = "2021-01-01")
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
stocks
# Out:
#              Adj Close                               Close              \
#                   AAPL         SPY        TSLA        AAPL         SPY
# Date
# 2019-01-02   37.943256  232.308777   20.674667   39.480000  250.179993
# 2019-01-03   34.163834  226.765244   20.024000   35.547501  244.210007
# 2019-01-04   35.622257  234.360901   21.179333   37.064999  252.389999
# 2019-01-07   35.542973  236.208771   22.330667   36.982498  254.380005
# 2019-01-08   36.220524  238.428009   22.356667   37.687500  256.769989
# ...                ...         ...         ...         ...         ...
# 2020-12-24  129.850555  355.649200  220.589996  131.970001  369.000000
# 2020-12-28  134.494797  358.704529  221.229996  136.690002  372.170013
# 2020-12-29  132.703979  358.020203  221.996674  134.869995  371.459991
# 2020-12-30  131.572479  358.530975  231.593338  133.720001  371.989990
# 2020-12-31  130.559036  360.352600  235.223328  132.690002  373.880005
#
# ...

# %%
stocks.head()
# Out:
#             Adj Close                             Close              \
#                  AAPL         SPY       TSLA       AAPL         SPY
# Date
# 2019-01-02  37.943256  232.308777  20.674667  39.480000  250.179993
# 2019-01-03  34.163834  226.765244  20.024000  35.547501  244.210007
# 2019-01-04  35.622257  234.360901  21.179333  37.064999  252.389999
# 2019-01-07  35.542973  236.208771  22.330667  36.982498  254.380005
# 2019-01-08  36.220524  238.428009  22.356667  37.687500  256.769989
#
#                             High                               Low  \
#                  TSLA       AAPL         SPY       TSLA       AAPL
# Date
# 2019-01-02  20.674667  39.712502  251.210007  21.008667  38.557499
# 2019-01-03  20.024000  36.430000  248.570007  20.626667  35.500000
# 2019-01-04  21.179333  37.137501  253.110001  21.200001  35.950001
# 2019-01-07  22.330667  37.207500  255.949997  22.449333  36.474998
# 2019-01-08  22.356667  37.955002  257.309998  22.934000  37.130001
#
# ...

# %%
stocks.tail()
# Out:
#              Adj Close                               Close              \
#                   AAPL         SPY        TSLA        AAPL         SPY
# Date
# 2020-12-24  129.850555  355.649200  220.589996  131.970001  369.000000
# 2020-12-28  134.494797  358.704529  221.229996  136.690002  372.170013
# 2020-12-29  132.703979  358.020203  221.996674  134.869995  371.459991
# 2020-12-30  131.572479  358.530975  231.593338  133.720001  371.989990
# 2020-12-31  130.559036  360.352600  235.223328  132.690002  373.880005
#
#                               High                                 Low  \
#                   TSLA        AAPL         SPY        TSLA        AAPL
# Date
# 2020-12-24  220.589996  133.460007  369.029999  222.029999  131.100006
# 2020-12-28  221.229996  137.339996  372.589996  227.133331  133.509995
# 2020-12-29  221.996674  138.789993  374.000000  223.300003  134.339996
# 2020-12-30  231.593338  135.990005  373.100006  232.199997  133.399994
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 505 entries, 2019-01-02 to 2020-12-31
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  505 non-null    float64
#  1   (Adj Close, SPY)   505 non-null    float64
#  2   (Adj Close, TSLA)  505 non-null    float64
#  3   (Close, AAPL)      505 non-null    float64
#  4   (Close, SPY)       505 non-null    float64
#  5   (Close, TSLA)      505 non-null    float64
#  6   (High, AAPL)       505 non-null    float64
#  7   (High, SPY)        505 non-null    float64
#  8   (High, TSLA)       505 non-null    float64
#  9   (Low, AAPL)        505 non-null    float64
#  10  (Low, SPY)         505 non-null    float64
#  11  (Low, TSLA)        505 non-null    float64
#  12  (Open, AAPL)       505 non-null    float64
#  13  (Open, SPY)        505 non-null    float64
#  14  (Open, TSLA)       505 non-null    float64
# ...

# %%
stocks.to_csv("stocksExample.csv")

# %%
stocks = pd.read_csv("stocksExample.csv")

# %%
stocks
# Out:
#      Unnamed: 0           Adj Close         Adj Close.1         Adj Close.2  \
# 0           NaN                AAPL                 SPY                TSLA
# 1          Date                 NaN                 NaN                 NaN
# 2    2019-01-02   37.94325637817383  232.30877685546875  20.674667358398438
# 3    2019-01-03   34.16383361816406  226.76524353027344   20.02400016784668
# 4    2019-01-04  35.622257232666016  234.36090087890625  21.179332733154297
# ..          ...                 ...                 ...                 ...
# 502  2020-12-24  129.85055541992188   355.6492004394531  220.58999633789062
# 503  2020-12-28   134.4947967529297  358.70452880859375  221.22999572753906
# 504  2020-12-29   132.7039794921875  358.02020263671875  221.99667358398438
# 505  2020-12-30  131.57247924804688   358.5309753417969   231.5933380126953
# 506  2020-12-31   130.5590362548828  360.35260009765625  235.22332763671875
#
# ...

# %%
stocks = pd.read_csv("stocksExample.csv", header = [0,1])

# %%
stocks
# Out:
#     Unnamed: 0_level_0   Adj Close                               Close  \
#     Unnamed: 0_level_1        AAPL         SPY        TSLA        AAPL
# 0                 Date         NaN         NaN         NaN         NaN
# 1           2019-01-02   37.943256  232.308777   20.674667   39.480000
# 2           2019-01-03   34.163834  226.765244   20.024000   35.547501
# 3           2019-01-04   35.622257  234.360901   21.179333   37.064999
# 4           2019-01-07   35.542973  236.208771   22.330667   36.982498
# ..                 ...         ...         ...         ...         ...
# 501         2020-12-24  129.850555  355.649200  220.589996  131.970001
# 502         2020-12-28  134.494797  358.704529  221.229996  136.690002
# 503         2020-12-29  132.703979  358.020203  221.996674  134.869995
# 504         2020-12-30  131.572479  358.530975  231.593338  133.720001
# 505         2020-12-31  130.559036  360.352600  235.223328  132.690002
#
# ...

# %%
stocks = pd.read_csv("stocksExample.csv", header = [0,1], index_col = [0])

# %%
stocks
# Out:
#              Adj Close                               Close              \
#                   AAPL         SPY        TSLA        AAPL         SPY
# Date
# 2019-01-02   37.943256  232.308777   20.674667   39.480000  250.179993
# 2019-01-03   34.163834  226.765244   20.024000   35.547501  244.210007
# 2019-01-04   35.622257  234.360901   21.179333   37.064999  252.389999
# 2019-01-07   35.542973  236.208771   22.330667   36.982498  254.380005
# 2019-01-08   36.220524  238.428009   22.356667   37.687500  256.769989
# ...                ...         ...         ...         ...         ...
# 2020-12-24  129.850555  355.649200  220.589996  131.970001  369.000000
# 2020-12-28  134.494797  358.704529  221.229996  136.690002  372.170013
# 2020-12-29  132.703979  358.020203  221.996674  134.869995  371.459991
# 2020-12-30  131.572479  358.530975  231.593338  133.720001  371.989990
# 2020-12-31  130.559036  360.352600  235.223328  132.690002  373.880005
#
# ...

# %%
stocks = pd.read_csv("stocksExample.csv", header = [0,1], index_col = [0], parse_dates = [0])

# %%
stocks
# Out:
#              Adj Close                               Close              \
#                   AAPL         SPY        TSLA        AAPL         SPY
# Date
# 2019-01-02   37.943256  232.308777   20.674667   39.480000  250.179993
# 2019-01-03   34.163834  226.765244   20.024000   35.547501  244.210007
# 2019-01-04   35.622257  234.360901   21.179333   37.064999  252.389999
# 2019-01-07   35.542973  236.208771   22.330667   36.982498  254.380005
# 2019-01-08   36.220524  238.428009   22.356667   37.687500  256.769989
# ...                ...         ...         ...         ...         ...
# 2020-12-24  129.850555  355.649200  220.589996  131.970001  369.000000
# 2020-12-28  134.494797  358.704529  221.229996  136.690002  372.170013
# 2020-12-29  132.703979  358.020203  221.996674  134.869995  371.459991
# 2020-12-30  131.572479  358.530975  231.593338  133.720001  371.989990
# 2020-12-31  130.559036  360.352600  235.223328  132.690002  373.880005
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',  'SPY'),
#             ('Adj Close', 'TSLA'),
#             (    'Close', 'AAPL'),
#             (    'Close',  'SPY'),
#             (    'Close', 'TSLA'),
#             (     'High', 'AAPL'),
#             (     'High',  'SPY'),
#             (     'High', 'TSLA'),
#             (      'Low', 'AAPL'),
#             (      'Low',  'SPY'),
#             (      'Low', 'TSLA'),
#             (     'Open', 'AAPL'),
#             (     'Open',  'SPY'),
#             (     'Open', 'TSLA'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',  'SPY'),
#             (   'Volume', 'TSLA')],
#            )

# %%
# This is to convert a multiple index to one tuple
stocks.columns = stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),  ('Adj Close', 'SPY'), ('Adj Close', 'TSLA'),
#            ('Close', 'AAPL'),      ('Close', 'SPY'),     ('Close', 'TSLA'),
#             ('High', 'AAPL'),       ('High', 'SPY'),      ('High', 'TSLA'),
#              ('Low', 'AAPL'),        ('Low', 'SPY'),       ('Low', 'TSLA'),
#             ('Open', 'AAPL'),       ('Open', 'SPY'),      ('Open', 'TSLA'),
#           ('Volume', 'AAPL'),     ('Volume', 'SPY'),    ('Volume', 'TSLA')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, SPY)  (Adj Close, TSLA)  \
# Date
# 2019-01-02          37.943256        232.308777          20.674667
# 2019-01-03          34.163834        226.765244          20.024000
# 2019-01-04          35.622257        234.360901          21.179333
# 2019-01-07          35.542973        236.208771          22.330667
# 2019-01-08          36.220524        238.428009          22.356667
# ...                       ...               ...                ...
# 2020-12-24         129.850555        355.649200         220.589996
# 2020-12-28         134.494797        358.704529         221.229996
# 2020-12-29         132.703979        358.020203         221.996674
# 2020-12-30         131.572479        358.530975         231.593338
# 2020-12-31         130.559036        360.352600         235.223328
#
#             (Close, AAPL)  (Close, SPY)  (Close, TSLA)  (High, AAPL)  \
# Date
# 2019-01-02      39.480000    250.179993      20.674667     39.712502
# ...

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)

# %%
stocks
# Out:
#              Adj Close                               Close              \
#                   AAPL         SPY        TSLA        AAPL         SPY
# Date
# 2019-01-02   37.943256  232.308777   20.674667   39.480000  250.179993
# 2019-01-03   34.163834  226.765244   20.024000   35.547501  244.210007
# 2019-01-04   35.622257  234.360901   21.179333   37.064999  252.389999
# 2019-01-07   35.542973  236.208771   22.330667   36.982498  254.380005
# 2019-01-08   36.220524  238.428009   22.356667   37.687500  256.769989
# ...                ...         ...         ...         ...         ...
# 2020-12-24  129.850555  355.649200  220.589996  131.970001  369.000000
# 2020-12-28  134.494797  358.704529  221.229996  136.690002  372.170013
# 2020-12-29  132.703979  358.020203  221.996674  134.869995  371.459991
# 2020-12-30  131.572479  358.530975  231.593338  133.720001  371.989990
# 2020-12-31  130.559036  360.352600  235.223328  132.690002  373.880005
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',  'SPY'),
#             ('Adj Close', 'TSLA'),
#             (    'Close', 'AAPL'),
#             (    'Close',  'SPY'),
#             (    'Close', 'TSLA'),
#             (     'High', 'AAPL'),
#             (     'High',  'SPY'),
#             (     'High', 'TSLA'),
#             (      'Low', 'AAPL'),
#             (      'Low',  'SPY'),
#             (      'Low', 'TSLA'),
#             (     'Open', 'AAPL'),
#             (     'Open',  'SPY'),
#             (     'Open', 'TSLA'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',  'SPY'),
#             (   'Volume', 'TSLA')],
#            )

# %%
# Creating a describe function 
stocks.describe()
# Out:
#         Adj Close                               Close                          \
#              AAPL         SPY        TSLA        AAPL         SPY        TSLA
# count  505.000000  505.000000  505.000000  505.000000  505.000000  505.000000
# mean    72.044788  289.466755   57.528172   73.748386  306.135960   57.528172
# std     27.089084   30.093402   55.979811   27.280933   29.185095   55.979811
# min     34.163834  212.184525   11.931333   35.547501  222.949997   11.931333
# 25%     49.228115  268.875641   17.361334   50.782501  286.660004   17.361334
# 50%     65.096138  282.169983   28.509333   66.730003  300.239990   28.509333
# 75%     89.843620  310.677521   80.577332   91.632500  326.859985   80.577332
# max    134.494797  360.352600  235.223328  136.690002  373.880005  235.223328
#
#              High                                 Low                          \
#              AAPL         SPY        TSLA        AAPL         SPY        TSLA
# ...

# %%
stocks.loc[:,"Close"]
# Out:
#                   AAPL         SPY        TSLA
# Date
# 2019-01-02   39.480000  250.179993   20.674667
# 2019-01-03   35.547501  244.210007   20.024000
# 2019-01-04   37.064999  252.389999   21.179333
# 2019-01-07   36.982498  254.380005   22.330667
# 2019-01-08   37.687500  256.769989   22.356667
# ...                ...         ...         ...
# 2020-12-24  131.970001  369.000000  220.589996
# 2020-12-28  136.690002  372.170013  221.229996
# 2020-12-29  134.869995  371.459991  221.996674
# 2020-12-30  133.720001  371.989990  231.593338
# 2020-12-31  132.690002  373.880005  235.223328
#
# [505 rows x 3 columns]

# %%
close = stocks.loc[:,"Close"].copy()

# %%
close
# Out:
#                   AAPL         SPY        TSLA
# Date
# 2019-01-02   39.480000  250.179993   20.674667
# 2019-01-03   35.547501  244.210007   20.024000
# 2019-01-04   37.064999  252.389999   21.179333
# 2019-01-07   36.982498  254.380005   22.330667
# 2019-01-08   37.687500  256.769989   22.356667
# ...                ...         ...         ...
# 2020-12-24  131.970001  369.000000  220.589996
# 2020-12-28  136.690002  372.170013  221.229996
# 2020-12-29  134.869995  371.459991  221.996674
# 2020-12-30  133.720001  371.989990  231.593338
# 2020-12-31  132.690002  373.880005  235.223328
#
# [505 rows x 3 columns]

# %%
# %matplotlib inline
plt.style.use("seaborn")

# %%
close.plot(figsize = (15,8), fontsize = 12)
plt.legend(fontsize = 12)
plt.show()

# %%
#normalize data 
close.iloc[0,0]
# Out:
# 39.47999954223633

# %%
close.AAPL
# Out:
# Date
# 2019-01-02     39.480000
# 2019-01-03     35.547501
# 2019-01-04     37.064999
# 2019-01-07     36.982498
# 2019-01-08     37.687500
#                  ...
# 2020-12-24    131.970001
# 2020-12-28    136.690002
# 2020-12-29    134.869995
# 2020-12-30    133.720001
# 2020-12-31    132.690002
# Name: AAPL, Length: 505, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0])
# Out:
# Date
# 2019-01-02    1.000000
# 2019-01-03    0.900393
# 2019-01-04    0.938830
# 2019-01-07    0.936740
# 2019-01-08    0.954597
#                 ...
# 2020-12-24    3.342705
# 2020-12-28    3.462259
# 2020-12-29    3.416160
# 2020-12-30    3.387031
# 2020-12-31    3.360942
# Name: AAPL, Length: 505, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2019-01-02    100.000000
# 2019-01-03     90.039263
# 2019-01-04     93.882976
# 2019-01-07     93.674009
# 2019-01-08     95.459728
#                  ...
# 2020-12-24    334.270524
# 2020-12-28    346.225947
# 2020-12-29    341.616000
# 2020-12-30    338.703148
# 2020-12-31    336.094235
# Name: AAPL, Length: 505, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL     39.480000
# SPY     250.179993
# TSLA     20.674667
# Name: 2019-01-02 00:00:00, dtype: float64

# %%
close.div(close.iloc[0]).mul(100)
# Out:
#                   AAPL         SPY         TSLA
# Date
# 2019-01-02  100.000000  100.000000   100.000000
# 2019-01-03   90.039263   97.613724    96.852829
# 2019-01-04   93.882976  100.883367   102.440984
# 2019-01-07   93.674009  101.678796   108.009803
# 2019-01-08   95.459728  102.634102   108.135556
# ...                ...         ...          ...
# 2020-12-24  334.270524  147.493809  1066.957898
# 2020-12-28  346.225947  148.760902  1070.053471
# 2020-12-29  341.616000  148.477097  1073.761767
# 2020-12-30  338.703148  148.688944  1120.179271
# 2020-12-31  336.094235  149.444406  1137.736939
#
# [505 rows x 3 columns]

# %%
normclose = close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize = (15,8), fontsize = 12)
plt.legend(fontsize = 12)
plt.show()

# %%
# this is better for analyzing graphs and not to incorrectly judge a stock

# %%
tsla = close.TSLA.copy().to_frame()

# %%
tsla
# Out:
#                   TSLA
# Date
# 2019-01-02   20.674667
# 2019-01-03   20.024000
# 2019-01-04   21.179333
# 2019-01-07   22.330667
# 2019-01-08   22.356667
# ...                ...
# 2020-12-24  220.589996
# 2020-12-28  221.229996
# 2020-12-29  221.996674
# 2020-12-30  231.593338
# 2020-12-31  235.223328
#
# [505 rows x 1 columns]

# %%
#learning shift function 
tsla.shift(periods = 1)
# Out:
#                   TSLA
# Date
# 2019-01-02         NaN
# 2019-01-03   20.674667
# 2019-01-04   20.024000
# 2019-01-07   21.179333
# 2019-01-08   22.330667
# ...                ...
# 2020-12-24  215.326660
# 2020-12-28  220.589996
# 2020-12-29  221.229996
# 2020-12-30  221.996674
# 2020-12-31  231.593338
#
# [505 rows x 1 columns]

# %%
tsla["lag1"] = tsla.shift(periods = 1)

# %%
tsla
# Out:
#                   TSLA        lag1
# Date
# 2019-01-02   20.674667         NaN
# 2019-01-03   20.024000   20.674667
# 2019-01-04   21.179333   20.024000
# 2019-01-07   22.330667   21.179333
# 2019-01-08   22.356667   22.330667
# ...                ...         ...
# 2020-12-24  220.589996  215.326660
# 2020-12-28  221.229996  220.589996
# 2020-12-29  221.996674  221.229996
# 2020-12-30  231.593338  221.996674
# 2020-12-31  235.223328  231.593338
#
# [505 rows x 2 columns]

# %%
#lag1 can be used to calc the daily changes which is important

# %%
tsla["diff"] = tsla.TSLA.sub(tsla.lag1)

# %%
tsla
# Out:
#                   TSLA        lag1      diff
# Date
# 2019-01-02   20.674667         NaN       NaN
# 2019-01-03   20.024000   20.674667 -0.650667
# 2019-01-04   21.179333   20.024000  1.155333
# 2019-01-07   22.330667   21.179333  1.151335
# 2019-01-08   22.356667   22.330667  0.025999
# ...                ...         ...       ...
# 2020-12-24  220.589996  215.326660  5.263336
# 2020-12-28  221.229996  220.589996  0.639999
# 2020-12-29  221.996674  221.229996  0.766678
# 2020-12-30  231.593338  221.996674  9.596664
# 2020-12-31  235.223328  231.593338  3.629990
#
# [505 rows x 3 columns]

# %%
# we need to divide the first day with the lag day
# and sub the lag day and subtract one and mult by 100
tsla["% Change"] = tsla.TSLA.div(tsla.lag1).sub(1).mul(100)

# %%
#these are most commonly used functions dealing w data frames

# %%
tsla
# Out:
#                   TSLA        lag1      diff  % Change     diff2  % Change 2
# Date
# 2019-01-02   20.674667         NaN       NaN       NaN       NaN         NaN
# 2019-01-03   20.024000   20.674667 -0.650667 -3.147171 -0.650667   -3.147171
# 2019-01-04   21.179333   20.024000  1.155333  5.769739  1.155333    5.769739
# 2019-01-07   22.330667   21.179333  1.151335  5.436124  1.151335    5.436124
# 2019-01-08   22.356667   22.330667  0.025999  0.116428  0.025999    0.116428
# ...                ...         ...       ...       ...       ...         ...
# 2020-12-24  220.589996  215.326660  5.263336  2.444350  5.263336    2.444350
# 2020-12-28  221.229996  220.589996  0.639999  0.290131  0.639999    0.290131
# 2020-12-29  221.996674  221.229996  0.766678  0.346552  0.766678    0.346552
# 2020-12-30  231.593338  221.996674  9.596664  4.322887  9.596664    4.322887
# 2020-12-31  235.223328  231.593338  3.629990  1.567398  3.629990    1.567398
#
# [505 rows x 6 columns]

# %%
tsla["diff2"] = tsla.TSLA.diff(periods = 1)
tsla
# Out:
#                   TSLA        lag1      diff  % Change     diff2
# Date
# 2019-01-02   20.674667         NaN       NaN       NaN       NaN
# 2019-01-03   20.024000   20.674667 -0.650667  0.968528 -0.650667
# 2019-01-04   21.179333   20.024000  1.155333  1.057697  1.155333
# 2019-01-07   22.330667   21.179333  1.151335  1.054361  1.151335
# 2019-01-08   22.356667   22.330667  0.025999  1.001164  0.025999
# ...                ...         ...       ...       ...       ...
# 2020-12-24  220.589996  215.326660  5.263336  1.024443  5.263336
# 2020-12-28  221.229996  220.589996  0.639999  1.002901  0.639999
# 2020-12-29  221.996674  221.229996  0.766678  1.003466  0.766678
# 2020-12-30  231.593338  221.996674  9.596664  1.043229  9.596664
# 2020-12-31  235.223328  231.593338  3.629990  1.015674  3.629990
#
# [505 rows x 5 columns]

# %%
# this is use of diff function both do the same thing

# %%
tsla["% Change 2"] = tsla.TSLA.pct_change(periods = 1).mul(100)

# %%
tsla
# Out:
#                   TSLA        lag1      diff  % Change     diff2  % Change 2
# Date
# 2019-01-02   20.674667         NaN       NaN       NaN       NaN         NaN
# 2019-01-03   20.024000   20.674667 -0.650667 -3.147171 -0.650667   -3.147171
# 2019-01-04   21.179333   20.024000  1.155333  5.769739  1.155333    5.769739
# 2019-01-07   22.330667   21.179333  1.151335  5.436124  1.151335    5.436124
# 2019-01-08   22.356667   22.330667  0.025999  0.116428  0.025999    0.116428
# ...                ...         ...       ...       ...       ...         ...
# 2020-12-24  220.589996  215.326660  5.263336  2.444350  5.263336    2.444350
# 2020-12-28  221.229996  220.589996  0.639999  0.290131  0.639999    0.290131
# 2020-12-29  221.996674  221.229996  0.766678  0.346552  0.766678    0.346552
# 2020-12-30  231.593338  221.996674  9.596664  4.322887  9.596664    4.322887
# 2020-12-31  235.223328  231.593338  3.629990  1.567398  3.629990    1.567398
#
# [505 rows x 6 columns]

# %%
del tsla["diff"]

# %%
tsla
# Out:
#                   TSLA  % Change
# Date
# 2019-01-02   20.674667       NaN
# 2019-01-03   20.024000 -3.147171
# 2019-01-04   21.179333  5.769739
# 2019-01-07   22.330667  5.436124
# 2019-01-08   22.356667  0.116428
# ...                ...       ...
# 2020-12-24  220.589996  2.444350
# 2020-12-28  221.229996  0.290131
# 2020-12-29  221.996674  0.346552
# 2020-12-30  231.593338  4.322887
# 2020-12-31  235.223328  1.567398
#
# [505 rows x 2 columns]

# %%
tsla.rename(columns = {'% Change':'Change'}, inplace = True)

# %%
tsla
# Out:
#                   TSLA    Change
# Date
# 2019-01-02   20.674667       NaN
# 2019-01-03   20.024000 -3.147171
# 2019-01-04   21.179333  5.769739
# 2019-01-07   22.330667  5.436124
# 2019-01-08   22.356667  0.116428
# ...                ...       ...
# 2020-12-24  220.589996  2.444350
# 2020-12-28  221.229996  0.290131
# 2020-12-29  221.996674  0.346552
# 2020-12-30  231.593338  4.322887
# 2020-12-31  235.223328  1.567398
#
# [505 rows x 2 columns]

# %%
# gives the last day of the month freq is monthly
tsla.TSLA.resample("M").last()
# Out:
# Date
# 2019-01-31     20.468000
# 2019-02-28     21.325333
# 2019-03-31     18.657333
# 2019-04-30     15.912667
# 2019-05-31     12.344000
# 2019-06-30     14.897333
# 2019-07-31     16.107332
# 2019-08-31     15.040667
# 2019-09-30     16.058001
# 2019-10-31     20.994667
# 2019-11-30     21.996000
# 2019-12-31     27.888666
# 2020-01-31     43.371334
# 2020-02-29     44.532665
# 2020-03-31     34.933334
# 2020-04-30     52.125332
# 2020-05-31     55.666668
# 2020-06-30     71.987335
# 2020-07-31     95.384003
# 2020-08-31    166.106674
# 2020-09-30    143.003326
# 2020-10-31    129.346664
# 2020-11-30    189.199997
# 2020-12-31    235.223328
# Freq: M, Name: TSLA, dtype: float64

# %%
# for last business day of the month 
tsla.TSLA.resample("BM").last()
# Out:
# Date
# 2019-01-31     20.468000
# 2019-02-28     21.325333
# 2019-03-29     18.657333
# 2019-04-30     15.912667
# 2019-05-31     12.344000
# 2019-06-28     14.897333
# 2019-07-31     16.107332
# 2019-08-30     15.040667
# 2019-09-30     16.058001
# 2019-10-31     20.994667
# 2019-11-29     21.996000
# 2019-12-31     27.888666
# 2020-01-31     43.371334
# 2020-02-28     44.532665
# 2020-03-31     34.933334
# 2020-04-30     52.125332
# 2020-05-29     55.666668
# 2020-06-30     71.987335
# 2020-07-31     95.384003
# 2020-08-31    166.106674
# 2020-09-30    143.003326
# 2020-10-30    129.346664
# 2020-11-30    189.199997
# 2020-12-31    235.223328
# Freq: BM, Name: TSLA, dtype: float64

# %%
# This above is how to handle data and how to fix and clean it

# %%
tsla
# Out:
#                   TSLA    Change
# Date
# 2019-01-02   20.674667       NaN
# 2019-01-03   20.024000 -3.147171
# 2019-01-04   21.179333  5.769739
# 2019-01-07   22.330667  5.436124
# 2019-01-08   22.356667  0.116428
# ...                ...       ...
# 2020-12-24  220.589996  2.444350
# 2020-12-28  221.229996  0.290131
# 2020-12-29  221.996674  0.346552
# 2020-12-30  231.593338  4.322887
# 2020-12-31  235.223328  1.567398
#
# [505 rows x 2 columns]

# %%
del tsla["Change"]

# %%
tsla
# Out:
#                   TSLA
# Date
# 2019-01-02   20.674667
# 2019-01-03   20.024000
# 2019-01-04   21.179333
# 2019-01-07   22.330667
# 2019-01-08   22.356667
# ...                ...
# 2020-12-24  220.589996
# 2020-12-28  221.229996
# 2020-12-29  221.996674
# 2020-12-30  231.593338
# 2020-12-31  235.223328
#
# [505 rows x 1 columns]

# %%
# any row with na data is removed and hence makes it cleaner 
ret = tsla.pct_change().dropna()

# %%
ret
# Out:
#                 TSLA
# Date
# 2019-01-03 -0.031472
# 2019-01-04  0.057697
# 2019-01-07  0.054361
# 2019-01-08  0.001164
# 2019-01-09  0.009483
# ...              ...
# 2020-12-24  0.024443
# 2020-12-28  0.002901
# 2020-12-29  0.003466
# 2020-12-30  0.043229
# 2020-12-31  0.015674
#
# [504 rows x 1 columns]

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 504 entries, 2019-01-03 to 2020-12-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TSLA    504 non-null    float64
# dtypes: float64(1)
# memory usage: 7.9 KB

# %%
ret.plot(kind = "hist", figsize = (12, 8), bins = 100)
plt.show()

# %%
daily_mean_return = ret.mean()

# %%
daily_mean_return
# Out:
# TSLA    0.005874
# dtype: float64

# %%
var_daily = ret.var()
var_daily
# Out:
# TSLA    0.002075
# dtype: float64

# %%
# Standard dev is the "risk metric" when doing quantitative analysis
# on any stock

# %%
std_daily = np.sqrt(var_daily)

# %%
std_daily
# Out:
# TSLA    0.045553
# dtype: float64

# %%
# we can calculate it another way as well
ret.std()
# Out:
# TSLA    0.045553
# dtype: float64

# %%
# annual return 
# 252 is the working days that are in a year
annual_mean_ret = daily_mean_return * 252
annual_mean_ret
# Out:
# TSLA    1.480213
# dtype: float64

# %%
annual_var_return = var_daily * 252
annual_var_return
# Out:
# TSLA    0.522921
# dtype: float64

# %%
annual_std_returns = np.sqrt(annual_var_return)
annual_std_returns
# Out:
# TSLA    0.723133
# dtype: float64

# %%
# yet another way to calculate standard deviation returns
# we leverage the std function instead of regular calculations
ret.std() * np.sqrt(252)
# Out:
# TSLA    0.723133
# dtype: float64

# %%
ticker = ["SPY", "AAPL", "TSLA", "MFA", "MSFT", "SNAP", "META"]

# %%
stocks = yf.download(ticker, start = "2017-01-01", end = "2023-01-01")
# Out:
# [*********************100%%**********************]  7 of 7 completed

# %%
close = stocks.loc[:,"Close"].copy()
normclose = close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize = (15, 8), fontsize = 12)
plt.legend(fontsize = 12)
plt.show()

# %%
ret = close.pct_change().dropna()
ret.head()
# Out:
#                 AAPL      META       MFA      MSFT      SNAP       SPY  \
# Date
# 2017-03-03  0.005901  0.002998  0.003718  0.003749  0.106618  0.000630
# 2017-03-06 -0.003148  0.001823 -0.002469  0.000311 -0.122554 -0.002978
# 2017-03-07  0.001292 -0.000873 -0.002475  0.002023 -0.098023 -0.002987
# 2017-03-08 -0.003727  0.003059 -0.019851  0.009161  0.063899 -0.001857
# 2017-03-09 -0.002302  0.003776  0.000000 -0.004001 -0.004384  0.001268
#
#                 TSLA
# Date
# 2017-03-03  0.004352
# 2017-03-06 -0.001431
# 2017-03-07 -0.010430
# 2017-03-08 -0.006919
# 2017-03-09 -0.007980

# %%
ret.describe()
# Out:
#               AAPL         META          MFA         MSFT         SNAP  \
# count  1469.000000  1469.000000  1469.000000  1469.000000  1469.000000
# mean      0.001098     0.000249     0.001141     0.001070     0.000501
# std       0.019978     0.025544     0.068678     0.018463     0.048717
# min      -0.128647    -0.263901    -0.866667    -0.147390    -0.430797
# 25%      -0.008111    -0.010110    -0.007463    -0.007168    -0.020533
# 50%       0.000766     0.000847     0.000000     0.001115    -0.000822
# 75%       0.011533     0.012624     0.006925     0.010342     0.020576
# max       0.119808     0.175936     2.166667     0.142169     0.588163
#
#                SPY         TSLA
# count  1469.000000  1469.000000
# mean      0.000403     0.002125
# std       0.012709     0.039153
# min      -0.109424    -0.210628
# 25%      -0.003971    -0.017750
# 50%       0.000595     0.001446
# 75%       0.006302     0.019830
# max       0.090603     0.198949

# %%
#we can also transpose the data 
ret.describe().T
# Out:
#        count      mean       std       min       25%       50%       75%  \
# AAPL  1469.0  0.001098  0.019978 -0.128647 -0.008111  0.000766  0.011533
# META  1469.0  0.000249  0.025544 -0.263901 -0.010110  0.000847  0.012624
# MFA   1469.0  0.001141  0.068678 -0.866667 -0.007463  0.000000  0.006925
# MSFT  1469.0  0.001070  0.018463 -0.147390 -0.007168  0.001115  0.010342
# SNAP  1469.0  0.000501  0.048717 -0.430797 -0.020533 -0.000822  0.020576
# SPY   1469.0  0.000403  0.012709 -0.109424 -0.003971  0.000595  0.006302
# TSLA  1469.0  0.002125  0.039153 -0.210628 -0.017750  0.001446  0.019830
#
#            max
# AAPL  0.119808
# META  0.175936
# MFA   2.166667
# MSFT  0.142169
# SNAP  0.588163
# SPY   0.090603
# TSLA  0.198949

# %%
# to get all the important data we need ie mean and standard dev
summary = ret.describe().T.loc[:,["mean", "std"]]
summary

# %%
summary["mean"] = summary["mean"] * 252
summary["std"] = summary["std"] * np.sqrt(252)
summary
# Out:
#             mean         std
# AAPL   69.723062   79.920731
# META   15.841824  102.187376
# MFA    72.484790  274.739736
# MSFT   67.949695   73.859568
# SNAP   31.845630  194.888138
# SPY    25.610731   50.841976
# TSLA  134.968205  156.625209

# %%
summary.plot.scatter(x = "std", y = "mean", figsize = (12,8), s = 50, fontsize = 15)
for i in summary.index:
    plt.annotate(i, xy = (summary.loc[i, "std"] + 0.002, summary.loc[i, "mean"] + 0.002), size = 15)
plt.xlabel("Annual risk (std)", fontsize = 15)
plt.ylabel("Annual return", fontsize = 15)
plt.title("Risk/Return", fontsize = 25)
plt.show()

# %% [markdown]
# ## Correlation and Covariance

# %%
ret
# Out:
#                 AAPL      META       MFA      MSFT      SNAP       SPY  \
# Date
# 2017-03-03  0.005901  0.002998  0.003718  0.003749  0.106618  0.000630
# 2017-03-06 -0.003148  0.001823 -0.002469  0.000311 -0.122554 -0.002978
# 2017-03-07  0.001292 -0.000873 -0.002475  0.002023 -0.098023 -0.002987
# 2017-03-08 -0.003727  0.003059 -0.019851  0.009161  0.063899 -0.001857
# 2017-03-09 -0.002302  0.003776  0.000000 -0.004001 -0.004384  0.001268
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-23 -0.002798  0.007855  0.000950  0.002267 -0.011521  0.005752
# 2022-12-27 -0.013878 -0.009827 -0.009488 -0.007414 -0.002331 -0.003944
# 2022-12-28 -0.030685 -0.010780 -0.039272 -0.010255 -0.001168 -0.012428
# 2022-12-29  0.028324  0.040131 -0.007976  0.027630  0.030409  0.018000
# 2022-12-30  0.002469  0.000665 -0.010050 -0.004938  0.015891 -0.002634
#
#                 TSLA
# Date
# 2017-03-03  0.004352
# 2017-03-06 -0.001431
# 2017-03-07 -0.010430
# ...

# %%
# finding the covariance
ret.cov()
# Out:
#           AAPL      META       MFA      MSFT      SNAP       SPY      TSLA
# AAPL  0.000399  0.000297  0.000092  0.000281  0.000287  0.000201  0.000359
# META  0.000297  0.000653  0.000073  0.000293  0.000515  0.000204  0.000338
# MFA   0.000092  0.000073  0.004717  0.000067  0.000252  0.000141  0.000236
# MSFT  0.000281  0.000293  0.000067  0.000341  0.000305  0.000198  0.000325
# SNAP  0.000287  0.000515  0.000252  0.000305  0.002373  0.000226  0.000522
# SPY   0.000201  0.000204  0.000141  0.000198  0.000226  0.000162  0.000234
# TSLA  0.000359  0.000338  0.000236  0.000325  0.000522  0.000234  0.001533

# %%
# finding the correlation
ret.corr()
# Out:
#           AAPL      META       MFA      MSFT      SNAP       SPY      TSLA
# AAPL  1.000000  0.582730  0.067335  0.762105  0.295019  0.793295  0.459251
# META  0.582730  1.000000  0.041626  0.621254  0.413688  0.628126  0.337857
# MFA   0.067335  0.041626  1.000000  0.053069  0.075382  0.161075  0.087782
# MSFT  0.762105  0.621254  0.053069  1.000000  0.338641  0.843528  0.450240
# SNAP  0.295019  0.413688  0.075382  0.338641  1.000000  0.365375  0.273450
# SPY   0.793295  0.628126  0.161075  0.843528  0.365375  1.000000  0.470455
# TSLA  0.459251  0.337857  0.087782  0.450240  0.273450  0.470455  1.000000

# %%
# creating a heat map
import seaborn as sns

# %%
plt.figure(figsize = (12, 8))
sns.set(font_scale = 1.4)
sns.heatmap(ret.corr(), cmap = "Reds", annot = True, annot_kws = {"size":15}, vmax = 0.6)
# Out:
# <AxesSubplot:>

# %%
# anything below 0.5 is good for no correlation so that if one 
# stock tanks the portfolio as a whole doesnt go to shit

# %% [markdown]
# ## Simple Returns and Log Returns

# %%
df = pd.DataFrame(index = [2017, 2018, 2019], data = [100, 50, 95], columns = ["Price"])

# %%
df
# Out:
#       Price
# 2017    100
# 2018     50
# 2019     95

# %%
simplereturns = df.pct_change().dropna()
simplereturns
# Out:
#       Price
# 2018   -0.5
# 2019    0.9

# %%
simplereturns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
# simple returns doesnt take into account the whole timeline
# the log returns comes into perspective as mean returns can be 
# very misleading

# %%
log_returns = np.log(df/df.shift(1)).dropna()
log_returns
# Out:
# /Users/zekereyes/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py:402: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
#          Price
# 2018 -0.693147
# 2019  0.641854

# %%
log_returns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
# calc from arithmetic perspective
100 * np.exp(log_returns.mean() * 2)
# Out:
# Price    95.0
# dtype: float64

# %%
# this is indeed the ending price on 2019 so correct

# %%
# as quantitative traders we need to appreciate the importance of 
# log returns

# %% [markdown]
# ## Creating Moving Averages

# %%
MFA = yf.download("MFA")
MFA
# Out:
# [*********************100%%**********************]  1 of 1 completed
#              Open   High    Low  Close  Adj Close  Volume
# Date
# 1998-04-13  37.00  37.25  36.00  36.50   1.984073    3000
# 1998-04-14  37.25  37.25  36.50  36.50   1.984073    3800
# 1998-04-15  36.25  36.50  36.00  36.50   1.984073    2475
# 1998-04-16  36.25  36.25  36.00  36.00   1.956893    2950
# 1998-04-17  36.25  37.00  36.25  36.25   1.970483    3450
# ...           ...    ...    ...    ...        ...     ...
# 2023-08-21  10.35  10.35  10.10  10.23  10.230000  537900
# 2023-08-22  10.25  10.33  10.10  10.18  10.180000  612200
# 2023-08-23  10.26  10.55  10.20  10.54  10.540000  812500
# 2023-08-24  10.49  10.61  10.42  10.46  10.460000  400300
# 2023-08-25  10.49  10.64  10.39  10.58  10.580000  500200
#
# [6386 rows x 6 columns]

# %%
# to_frame() makes it into a nice table 
mfa = MFA.Close.to_frame()
mfa
# Out:
#             Close
# Date
# 1998-04-13  36.50
# 1998-04-14  36.50
# 1998-04-15  36.50
# 1998-04-16  36.00
# 1998-04-17  36.25
# ...           ...
# 2023-08-21  10.23
# 2023-08-22  10.18
# 2023-08-23  10.54
# 2023-08-24  10.46
# 2023-08-25  10.58
#
# [6386 rows x 1 columns]

# %%
mfa.plot(figsize = (12, 8), fontsize = 15)
plt.legend(loc = "upper left", fontsize = 15)
plt.show()

# %%
# Using a rolling function
mfa_roll = mfa.rolling(window = 10)

# %%
mfa_roll = mfa_roll.mean()
mfa_roll
# Out:
#              Close
# Date
# 1998-04-13     NaN
# 1998-04-14     NaN
# 1998-04-15     NaN
# 1998-04-16     NaN
# 1998-04-17     NaN
# ...            ...
# 2023-08-21  10.512
# 2023-08-22  10.440
# 2023-08-23  10.408
# 2023-08-24  10.386
# 2023-08-25  10.381
#
# [6386 rows x 1 columns]

# %%
mfa_roll.head(15)
# Out:
#              Close
# Date
# 1998-04-13     NaN
# 1998-04-14     NaN
# 1998-04-15     NaN
# 1998-04-16     NaN
# 1998-04-17     NaN
# 1998-04-20     NaN
# 1998-04-21     NaN
# 1998-04-22     NaN
# 1998-04-23     NaN
# 1998-04-24  37.100
# 1998-04-27  37.250
# 1998-04-28  37.475
# 1998-04-29  37.675
# 1998-04-30  37.950
# 1998-05-01  38.175

# %%
mfa.rolling(window = 10).median()
# Out:
#              Close
# Date
# 1998-04-13     NaN
# 1998-04-14     NaN
# 1998-04-15     NaN
# 1998-04-16     NaN
# 1998-04-17     NaN
# ...            ...
# 2023-08-21  10.500
# 2023-08-22  10.405
# 2023-08-23  10.405
# 2023-08-24  10.405
# 2023-08-25  10.405
#
# [6386 rows x 1 columns]

# %%
mfa.rolling(window = 10, min_periods = 5).max().head(15)
# Out:
#             Close
# Date
# 1998-04-13    NaN
# 1998-04-14    NaN
# 1998-04-15    NaN
# 1998-04-16    NaN
# 1998-04-17  36.50
# 1998-04-20  37.25
# 1998-04-21  37.50
# 1998-04-22  39.25
# 1998-04-23  39.25
# 1998-04-24  39.25
# 1998-04-27  39.25
# 1998-04-28  39.25
# 1998-04-29  39.25
# 1998-04-30  39.25
# 1998-05-01  39.25

# %%
mfa
# Out:
#             Close
# Date
# 1998-04-13  36.50
# 1998-04-14  36.50
# 1998-04-15  36.50
# 1998-04-16  36.00
# 1998-04-17  36.25
# ...           ...
# 2023-08-21  10.23
# 2023-08-22  10.18
# 2023-08-23  10.54
# 2023-08-24  10.46
# 2023-08-25  10.58
#
# [6386 rows x 1 columns]

# %%
# Creating 50 day moving average
mfa["SMA50"] = mfa.rolling(window = 50, min_periods = 50).mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/kf/521yqq6n4bl3dqsbd2dd0z1h0000gn/T/ipykernel_39311/631655049.py in <module>
#       1 # Creating 50 day moving average
# ----> 2 mfa["SMA50"] = mfa.rolling(window = 50, min_periods = 50).mean()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3643             self._setitem_array(key, value)
#    3644         elif isinstance(value, DataFrame):
# -> 3645             self._set_item_frame_value(key, value)
#    3646         elif (
#    3647             is_list_like(value)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _set_item_frame_value(self, key, value)
#    3773             len_cols = 1 if is_scalar(cols) else len(cols)
#    3774             if len_cols != len(value.columns):
# ...

# %%
mfa
# Out:
#             Close    SMA50
# Date
# 1998-04-13  36.50      NaN
# 1998-04-14  36.50      NaN
# 1998-04-15  36.50      NaN
# 1998-04-16  36.00      NaN
# 1998-04-17  36.25      NaN
# ...           ...      ...
# 2023-08-21  10.23  11.1192
# 2023-08-22  10.18  11.0978
# 2023-08-23  10.54  11.0800
# 2023-08-24  10.46  11.0594
# 2023-08-25  10.58  11.0412
#
# [6386 rows x 2 columns]

# %%
mfa.plot(figsize = (12, 8), fontsize = 15)
plt.legend(loc = "upper left", fontsize = 15)
plt.show()

# %%
# We need to specify close so there is no conflict in the table
mfa["SMA200"] = mfa.Close.rolling(window = 200, min_periods = 200).mean()
mfa
# Out:
#             Close    SMA50   SMA200
# Date
# 1998-04-13  36.50      NaN      NaN
# 1998-04-14  36.50      NaN      NaN
# 1998-04-15  36.50      NaN      NaN
# 1998-04-16  36.00      NaN      NaN
# 1998-04-17  36.25      NaN      NaN
# ...           ...      ...      ...
# 2023-08-21  10.23  11.1192  10.7224
# 2023-08-22  10.18  11.0978  10.7247
# 2023-08-23  10.54  11.0800  10.7298
# 2023-08-24  10.46  11.0594  10.7312
# 2023-08-25  10.58  11.0412  10.7332
#
# [6386 rows x 3 columns]

# %%
mfa.plot(figsize = (12, 8), fontsize = 15)
plt.legend(loc = "upper left", fontsize = 15)
plt.show()

# %%
mfa["EMA100"] = mfa.Close.ewm(span = 100, min_periods = 100).mean()

# %%
mfa
# Out:
#             Close    SMA50   SMA200     EMA100
# Date
# 1998-04-13  36.50      NaN      NaN        NaN
# 1998-04-14  36.50      NaN      NaN        NaN
# 1998-04-15  36.50      NaN      NaN        NaN
# 1998-04-16  36.00      NaN      NaN        NaN
# 1998-04-17  36.25      NaN      NaN        NaN
# ...           ...      ...      ...        ...
# 2023-08-21  10.23  11.1192  10.7224  10.841984
# 2023-08-22  10.18  11.0978  10.7247  10.828875
# 2023-08-23  10.54  11.0800  10.7298  10.823155
# 2023-08-24  10.46  11.0594  10.7312  10.815964
# 2023-08-25  10.58  11.0412  10.7332  10.811291
#
# [6386 rows x 4 columns]

# %%
mfa.plot(figsize = (12, 8), fontsize = 15)
plt.legend(loc = "upper left", fontsize = 15)
plt.show()

# %%
# this gives the days of specified days
mfa["Day"] = mfa.index.day_name()

# %%
mfa
# Out:
#             Close    SMA50   SMA200     EMA100        Day
# Date
# 1998-04-13  36.50      NaN      NaN        NaN     Monday
# 1998-04-14  36.50      NaN      NaN        NaN    Tuesday
# 1998-04-15  36.50      NaN      NaN        NaN  Wednesday
# 1998-04-16  36.00      NaN      NaN        NaN   Thursday
# 1998-04-17  36.25      NaN      NaN        NaN     Friday
# ...           ...      ...      ...        ...        ...
# 2023-08-21  10.23  11.1192  10.7224  10.841984     Monday
# 2023-08-22  10.18  11.0978  10.7247  10.828875    Tuesday
# 2023-08-23  10.54  11.0800  10.7298  10.823155  Wednesday
# 2023-08-24  10.46  11.0594  10.7312  10.815964   Thursday
# 2023-08-25  10.58  11.0412  10.7332  10.811291     Friday
#
# [6386 rows x 5 columns]

# %%
mfa["Quarter"] = mfa.index.quarter

# %%
mfa
# Out:
#             Close    SMA50   SMA200     EMA100        Day  Quarter
# Date
# 1998-04-13  36.50      NaN      NaN        NaN     Monday        2
# 1998-04-14  36.50      NaN      NaN        NaN    Tuesday        2
# 1998-04-15  36.50      NaN      NaN        NaN  Wednesday        2
# 1998-04-16  36.00      NaN      NaN        NaN   Thursday        2
# 1998-04-17  36.25      NaN      NaN        NaN     Friday        2
# ...           ...      ...      ...        ...        ...      ...
# 2023-08-21  10.23  11.1192  10.7224  10.841984     Monday        3
# 2023-08-22  10.18  11.0978  10.7247  10.828875    Tuesday        3
# 2023-08-23  10.54  11.0800  10.7298  10.823155  Wednesday        3
# 2023-08-24  10.46  11.0594  10.7312  10.815964   Thursday        3
# 2023-08-25  10.58  11.0412  10.7332  10.811291     Friday        3
#
# [6386 rows x 6 columns]

# %%
# Re-indexing

# %%
MFA =  yf.download("MFA")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
mfa = MFA.Close.to_frame()
mfa
# Out:
#             Close
# Date
# 1998-04-13  36.50
# 1998-04-14  36.50
# 1998-04-15  36.50
# 1998-04-16  36.00
# 1998-04-17  36.25
# ...           ...
# 2023-08-21  10.23
# 2023-08-22  10.18
# 2023-08-23  10.54
# 2023-08-24  10.46
# 2023-08-25  10.58
#
# [6386 rows x 1 columns]

# %%
all_days = pd.date_range(start = "2010-12-31", end = "2023-01-01", freq = "D")
all_days
# Out:
# DatetimeIndex(['2010-12-31', '2011-01-01', '2011-01-02', '2011-01-03',
#                '2011-01-04', '2011-01-05', '2011-01-06', '2011-01-07',
#                '2011-01-08', '2011-01-09',
#                ...
#                '2022-12-23', '2022-12-24', '2022-12-25', '2022-12-26',
#                '2022-12-27', '2022-12-28', '2022-12-29', '2022-12-30',
#                '2022-12-31', '2023-01-01'],
#               dtype='datetime64[ns]', length=4385, freq='D')

# %%
mfa
# Out:
#             Close
# Date
# 1998-04-13  36.50
# 1998-04-14  36.50
# 1998-04-15  36.50
# 1998-04-16  36.00
# 1998-04-17  36.25
# ...           ...
# 2023-08-21  10.23
# 2023-08-22  10.18
# 2023-08-23  10.54
# 2023-08-24  10.46
# 2023-08-25  10.58
#
# [6386 rows x 1 columns]

# %%
mfa = mfa.reindex(all_days)

# %%
mfa
# Out:
#                 Close
# 2010-12-31  32.639999
# 2011-01-01        NaN
# 2011-01-02        NaN
# 2011-01-03  32.360001
# 2011-01-04  31.559999
# ...               ...
# 2022-12-28  10.030000
# 2022-12-29   9.950000
# 2022-12-30   9.850000
# 2022-12-31        NaN
# 2023-01-01        NaN
#
# [4385 rows x 1 columns]

# %%
# to replace nan do forward and backwards fill

# %%
mfa.fillna(method = "ffill")
# Out:
#                 Close
# 2010-12-31  32.639999
# 2011-01-01  32.639999
# 2011-01-02  32.639999
# 2011-01-03  32.360001
# 2011-01-04  31.559999
# ...               ...
# 2022-12-28  10.030000
# 2022-12-29   9.950000
# 2022-12-30   9.850000
# 2022-12-31   9.850000
# 2023-01-01   9.850000
#
# [4385 rows x 1 columns]

# %%
mfa.fillna(method = "bfill")
# Out:
#                 Close
# 2010-12-31  32.639999
# 2011-01-01  32.360001
# 2011-01-02  32.360001
# 2011-01-03  32.360001
# 2011-01-04  31.559999
# ...               ...
# 2022-12-28  10.030000
# 2022-12-29   9.950000
# 2022-12-30   9.850000
# 2022-12-31        NaN
# 2023-01-01        NaN
#
# [4385 rows x 1 columns]

# %%
# this is how to fix data esp with weekends and such

# %%
MFA = yf.download("MFA", interval = "1wk")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
MFA
# Out:
#              Open   High    Low  Close  Adj Close   Volume
# Date
# 1998-04-13  37.00  37.25  36.00  36.25   1.970484    15675
# 1998-04-20  37.00  39.25  36.25  38.50   2.092788    37275
# 1998-04-27  39.00  39.50  37.50  38.50   2.092788    16600
# 1998-05-04  38.25  38.75  36.00  38.00   2.065609    20325
# 1998-05-11  38.00  38.50  36.25  37.75   2.052021    24200
# ...           ...    ...    ...    ...        ...      ...
# 2023-07-24  11.57  11.85  11.47  11.60  11.600000  4583600
# 2023-07-31  11.68  11.68  10.47  10.79  10.790000  6812100
# 2023-08-07  10.83  10.97  10.57  10.63  10.630000  3053100
# 2023-08-14  10.62  10.65  10.03  10.27  10.270000  3122400
# 2023-08-21  10.35  10.64  10.10  10.58  10.580000  3329971
#
# [1324 rows x 6 columns]

# %% [markdown]
# ## Cummulative Returns, Drawdowns etc...

# %%
meta = yf.download("META")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
meta = meta.Close.to_frame()

# %%
meta.Close
# Out:
# Date
# 2012-05-18     38.230000
# 2012-05-21     34.029999
# 2012-05-22     31.000000
# 2012-05-23     32.000000
# 2012-05-24     33.029999
#                  ...
# 2023-08-21    289.899994
# 2023-08-22    287.600006
# 2023-08-23    294.239990
# 2023-08-24    286.750000
# 2023-08-25    285.500000
# Name: Close, Length: 2836, dtype: float64

# %%
meta["d_returns"] = np.log(meta.div(meta.shift(1)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/kf/521yqq6n4bl3dqsbd2dd0z1h0000gn/T/ipykernel_39311/875258930.py in <module>
# ----> 1 meta["d_returns"] = np.log(meta.div(meta.shift(1)))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3643             self._setitem_array(key, value)
#    3644         elif isinstance(value, DataFrame):
# -> 3645             self._set_item_frame_value(key, value)
#    3646         elif (
#    3647             is_list_like(value)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _set_item_frame_value(self, key, value)
#    3773             len_cols = 1 if is_scalar(cols) else len(cols)
#    3774             if len_cols != len(value.columns):
# -> 3775                 raise ValueError("Columns must be same length as key")
#    3776
# ...

# %%
meta
# Out:
#                  Close  d_returns
# Date
# 2012-05-18   38.230000        NaN
# 2012-05-21   34.029999  -0.116378
# 2012-05-22   31.000000  -0.093255
# 2012-05-23   32.000000   0.031749
# 2012-05-24   33.029999   0.031680
# ...                ...        ...
# 2023-08-21  289.899994   0.023206
# 2023-08-22  287.600006  -0.007965
# 2023-08-23  294.239990   0.022825
# 2023-08-24  286.750000  -0.025785
# 2023-08-25  285.500000  -0.004369
#
# [2836 rows x 2 columns]

# %%
meta.dropna(inplace = True)

# %%
meta
# Out:
#                  Close  d_returns
# Date
# 2012-05-21   34.029999  -0.116378
# 2012-05-22   31.000000  -0.093255
# 2012-05-23   32.000000   0.031749
# 2012-05-24   33.029999   0.031680
# 2012-05-25   31.910000  -0.034497
# ...                ...        ...
# 2023-08-21  289.899994   0.023206
# 2023-08-22  287.600006  -0.007965
# 2023-08-23  294.239990   0.022825
# 2023-08-24  286.750000  -0.025785
# 2023-08-25  285.500000  -0.004369
#
# [2835 rows x 2 columns]

# %%
meta.d_returns.sum()
# Out:
# 2.0106498325705227

# %%
# what we would we get if we invested one dollar on 2012
np.exp(meta.d_returns.sum())
# Out:
# 7.468168830170691

# %%
meta["cumm_returns"] = meta.d_returns.cumsum().apply(np.exp)

# %%
meta
# Out:
#                  Close  d_returns  cumm_returns
# Date
# 2012-05-21   34.029999  -0.116378      0.890139
# 2012-05-22   31.000000  -0.093255      0.810882
# 2012-05-23   32.000000   0.031749      0.837039
# 2012-05-24   33.029999   0.031680      0.863981
# 2012-05-25   31.910000  -0.034497      0.834685
# ...                ...        ...           ...
# 2023-08-21  289.899994   0.023206      7.583264
# 2023-08-22  287.600006  -0.007965      7.523101
# 2023-08-23  294.239990   0.022825      7.696791
# 2023-08-24  286.750000  -0.025785      7.500867
# 2023-08-25  285.500000  -0.004369      7.468169
#
# [2835 rows x 3 columns]

# %%
# plot the graph of this dollar value invested
meta.cumm_returns.plot(figsize = (12, 8), title = "Meta Buy and Hold", fontsize = 12)
plt.show()

# %%
meta.d_returns.mean() * 252
# Out:
# 0.17872442956182397

# %%
# std aka risk metric 
meta.d_returns.std() * np.sqrt(252)
# Out:
# 0.4056932110628628

# %%
# find cumm maximum to find drawdowns 
# need to find the peak and valleys 
meta["cumm_max"] = meta.cumm_returns.cummax()
meta
# Out:
#                  Close  d_returns  cumm_returns  cumm_max
# Date
# 2012-05-21   34.029999  -0.116378      0.890139  0.890139
# 2012-05-22   31.000000  -0.093255      0.810882  0.890139
# 2012-05-23   32.000000   0.031749      0.837039  0.890139
# 2012-05-24   33.029999   0.031680      0.863981  0.890139
# 2012-05-25   31.910000  -0.034497      0.834685  0.890139
# ...                ...        ...           ...       ...
# 2023-08-21  289.899994   0.023206      7.583264  9.997095
# 2023-08-22  287.600006  -0.007965      7.523101  9.997095
# 2023-08-23  294.239990   0.022825      7.696791  9.997095
# 2023-08-24  286.750000  -0.025785      7.500867  9.997095
# 2023-08-25  285.500000  -0.004369      7.468169  9.997095
#
# [2835 rows x 4 columns]

# %%
meta[["cumm_returns", "cumm_max"]].plot(figsize = (12, 8), title = "Meta Buy and Hold + Cumm Max", fontsize = 12)
plt.show()

# %%
# Beneficial for breakout strategies

# %%
meta["drawdown"] = meta["cumm_max"] - meta["cumm_returns"]

# %%
meta
# Out:
#                  Close  d_returns  cumm_returns  cumm_max  drawdown
# Date
# 2012-05-21   34.029999  -0.116378      0.890139  0.890139  0.000000
# 2012-05-22   31.000000  -0.093255      0.810882  0.890139  0.079257
# 2012-05-23   32.000000   0.031749      0.837039  0.890139  0.053100
# 2012-05-24   33.029999   0.031680      0.863981  0.890139  0.026157
# 2012-05-25   31.910000  -0.034497      0.834685  0.890139  0.055454
# ...                ...        ...           ...       ...       ...
# 2023-08-21  289.899994   0.023206      7.583264  9.997095  2.413830
# 2023-08-22  287.600006  -0.007965      7.523101  9.997095  2.473994
# 2023-08-23  294.239990   0.022825      7.696791  9.997095  2.300304
# 2023-08-24  286.750000  -0.025785      7.500867  9.997095  2.496228
# 2023-08-25  285.500000  -0.004369      7.468169  9.997095  2.528926
#
# [2835 rows x 5 columns]

# %%
meta.drawdown.max()
# Out:
# 7.671372957834009

# %%
meta.drawdown.idxmax()
# Out:
# Timestamp('2022-11-03 00:00:00')

# %%
meta.loc[(meta.index <= '2022-11-03')]
# Out:
#                 Close  d_returns  cumm_returns  cumm_max  drawdown
# Date
# 2012-05-21  34.029999  -0.116378      0.890139  0.890139  0.000000
# 2012-05-22  31.000000  -0.093255      0.810882  0.890139  0.079257
# 2012-05-23  32.000000   0.031749      0.837039  0.890139  0.053100
# 2012-05-24  33.029999   0.031680      0.863981  0.890139  0.026157
# 2012-05-25  31.910000  -0.034497      0.834685  0.890139  0.055454
# ...               ...        ...           ...       ...       ...
# 2022-10-28  99.199997   0.012783      2.594889  9.997095  7.402206
# 2022-10-31  93.160004  -0.062819      2.436894  9.997095  7.560201
# 2022-11-01  95.199997   0.021661      2.490256  9.997095  7.506838
# 2022-11-02  90.540001  -0.050188      2.368360  9.997095  7.628735
# 2022-11-03  88.910004  -0.018167      2.325722  9.997095  7.671373
#
# [2633 rows x 5 columns]

# %%
# percentage drawdown
meta["drawdown %"] = (meta["cumm_max"] - meta["cumm_returns"]) / meta["cumm_max"]

# %%
 meta
# Out:
#                  Close  d_returns  cumm_returns  cumm_max  drawdown  \
# Date
# 2012-05-21   34.029999  -0.116378      0.890139  0.890139  0.000000
# 2012-05-22   31.000000  -0.093255      0.810882  0.890139  0.079257
# 2012-05-23   32.000000   0.031749      0.837039  0.890139  0.053100
# 2012-05-24   33.029999   0.031680      0.863981  0.890139  0.026157
# 2012-05-25   31.910000  -0.034497      0.834685  0.890139  0.055454
# ...                ...        ...           ...       ...       ...
# 2023-08-21  289.899994   0.023206      7.583264  9.997095  2.413830
# 2023-08-22  287.600006  -0.007965      7.523101  9.997095  2.473994
# 2023-08-23  294.239990   0.022825      7.696791  9.997095  2.300304
# 2023-08-24  286.750000  -0.025785      7.500867  9.997095  2.496228
# 2023-08-25  285.500000  -0.004369      7.468169  9.997095  2.528926
#
#             drawdown %
# Date
# 2012-05-21    0.000000
# 2012-05-22    0.089039
# 2012-05-23    0.059653
# 2012-05-24    0.029386
# ...

# %%
meta["drawdown %"].max()
# Out:
# 0.76736022980405

# %%
meta["drawdown %"].idxmax()
# Out:
# Timestamp('2022-11-03 00:00:00')

# %%
meta.loc[(meta.index <= '2022-11-03')]
# Out:
#                 Close  d_returns  cumm_returns  cumm_max  drawdown  drawdown %
# Date
# 2012-05-21  34.029999  -0.116378      0.890139  0.890139  0.000000    0.000000
# 2012-05-22  31.000000  -0.093255      0.810882  0.890139  0.079257    0.089039
# 2012-05-23  32.000000   0.031749      0.837039  0.890139  0.053100    0.059653
# 2012-05-24  33.029999   0.031680      0.863981  0.890139  0.026157    0.029386
# 2012-05-25  31.910000  -0.034497      0.834685  0.890139  0.055454    0.062298
# ...               ...        ...           ...       ...       ...         ...
# 2022-10-28  99.199997   0.012783      2.594889  9.997095  7.402206    0.740436
# 2022-10-31  93.160004  -0.062819      2.436894  9.997095  7.560201    0.756240
# 2022-11-01  95.199997   0.021661      2.490256  9.997095  7.506838    0.750902
# 2022-11-02  90.540001  -0.050188      2.368360  9.997095  7.628735    0.763095
# 2022-11-03  88.910004  -0.018167      2.325722  9.997095  7.671373    0.767360
#
# ...

# %% [markdown]
# ## SMA Strategy

# %%
data = meta.Close.loc[(meta.index >= '2012-5-21')]

# %%
data = data.to_frame()

# %%
data
# Out:
#                  Close
# Date
# 2012-05-21   34.029999
# 2012-05-22   31.000000
# 2012-05-23   32.000000
# 2012-05-24   33.029999
# 2012-05-25   31.910000
# ...                ...
# 2023-08-21  289.899994
# 2023-08-22  287.600006
# 2023-08-23  294.239990
# 2023-08-24  286.750000
# 2023-08-25  285.500000
#
# [2835 rows x 1 columns]

# %%
# create 2 MA
sma_s = 50
sma_l = 100

# %%
data["sma_s"] = data.Close.rolling(sma_s).mean()
data["sma_l"]= data.Close.rolling(sma_l).mean()

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 2012-05-21   34.029999         NaN         NaN
# 2012-05-22   31.000000         NaN         NaN
# 2012-05-23   32.000000         NaN         NaN
# 2012-05-24   33.029999         NaN         NaN
# 2012-05-25   31.910000         NaN         NaN
# ...                ...         ...         ...
# 2023-08-21  289.899994  296.572401  265.504701
# 2023-08-22  287.600006  297.025400  266.327201
# 2023-08-23  294.239990  297.489200  267.191201
# 2023-08-24  286.750000  297.797800  267.939301
# 2023-08-25  285.500000  298.040800  268.663600
#
# [2835 rows x 3 columns]

# %%
data.plot(figsize = (12, 8), title = "META - SMA{} | SMA{}".format(sma_s, sma_l), fontsize = 12)
# Out:
# <AxesSubplot:title={'center':'META - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc["2023"].plot(figsize = (12, 8), title = "META - SMA{} | SMA{}".format(sma_s, sma_l), fontsize = 12)
# Out:
# <AxesSubplot:title={'center':'META - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 2012-10-10   19.639999   20.472800   24.990700
# 2012-10-11   19.750000   20.450200   24.847900
# 2012-10-12   19.520000   20.439800   24.733100
# 2012-10-15   19.520000   20.408400   24.608300
# 2012-10-16   19.480000   20.359600   24.472800
# ...                ...         ...         ...
# 2023-08-21  289.899994  296.572401  265.504701
# 2023-08-22  287.600006  297.025400  266.327201
# 2023-08-23  294.239990  297.489200  267.191201
# 2023-08-24  286.750000  297.797800  267.939301
# 2023-08-25  285.500000  298.040800  268.663600
#
# [2736 rows x 3 columns]

# %%
# if sma_s > sma_l we go long otherwise we go short 
# because its -1

# %%
data["position"] = np.where(data["sma_s"] > data["sma_l"], 1, -1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position
# Date
# 2012-10-10   19.639999   20.472800   24.990700        -1
# 2012-10-11   19.750000   20.450200   24.847900        -1
# 2012-10-12   19.520000   20.439800   24.733100        -1
# 2012-10-15   19.520000   20.408400   24.608300        -1
# 2012-10-16   19.480000   20.359600   24.472800        -1
# ...                ...         ...         ...       ...
# 2023-08-21  289.899994  296.572401  265.504701         1
# 2023-08-22  287.600006  297.025400  266.327201         1
# 2023-08-23  294.239990  297.489200  267.191201         1
# 2023-08-24  286.750000  297.797800  267.939301         1
# 2023-08-25  285.500000  298.040800  268.663600         1
#
# [2736 rows x 4 columns]

# %%
# plot this table

# %%
data.loc[:,["sma_s", "sma_l", "position"]].plot(figsize = (12, 8), title = "META - SMA{} | SMA{}".format(sma_s, sma_l), fontsize = 12, secondary_y = "position")
# Out:
# <AxesSubplot:title={'center':'META - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc["2023",["sma_s", "sma_l", "position"]].plot(figsize = (12, 8), title = "META - SMA{} | SMA{}".format(sma_s, sma_l), fontsize = 12, secondary_y = "position")
# Out:
# <AxesSubplot:title={'center':'META - SMA50 | SMA100'}, xlabel='Date'>

# %% [markdown]
# ## Backtesting

# %%
data["returnsb&h"] = np.log(data.Close.div(data.Close.shift(1)))
# Out:
# /Users/zekereyes/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h
# Date
# 2012-10-10   19.639999   20.472800   24.990700        -1         NaN
# 2012-10-11   19.750000   20.450200   24.847900        -1    0.005585
# 2012-10-12   19.520000   20.439800   24.733100        -1   -0.011714
# 2012-10-15   19.520000   20.408400   24.608300        -1    0.000000
# 2012-10-16   19.480000   20.359600   24.472800        -1   -0.002051
# ...                ...         ...         ...       ...         ...
# 2023-08-21  289.899994  296.572401  265.504701         1    0.023206
# 2023-08-22  287.600006  297.025400  266.327201         1   -0.007965
# 2023-08-23  294.239990  297.489200  267.191201         1    0.022825
# 2023-08-24  286.750000  297.797800  267.939301         1   -0.025785
# 2023-08-25  285.500000  298.040800  268.663600         1   -0.004369
#
# [2736 rows x 5 columns]

# %%
data["strategy"] = data["returnsb&h"] * data.position.shift(1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  strategy
# Date
# 2012-10-10   19.639999   20.472800   24.990700        -1         NaN       NaN
# 2012-10-11   19.750000   20.450200   24.847900        -1    0.005585 -0.005585
# 2012-10-12   19.520000   20.439800   24.733100        -1   -0.011714  0.011714
# 2012-10-15   19.520000   20.408400   24.608300        -1    0.000000 -0.000000
# 2012-10-16   19.480000   20.359600   24.472800        -1   -0.002051  0.002051
# ...                ...         ...         ...       ...         ...       ...
# 2023-08-21  289.899994  296.572401  265.504701         1    0.023206  0.023206
# 2023-08-22  287.600006  297.025400  266.327201         1   -0.007965 -0.007965
# 2023-08-23  294.239990  297.489200  267.191201         1    0.022825  0.022825
# 2023-08-24  286.750000  297.797800  267.939301         1   -0.025785 -0.025785
# 2023-08-25  285.500000  298.040800  268.663600         1   -0.004369 -0.004369
#
# ...

# %%
data.dropna(inplace = True)

# %%
data[["returnsb&h", "strategy"]].sum()
# Out:
# returnsb&h    2.676674
# strategy      0.013119
# dtype: float64

# %%
# this is a comparison to buy and hold

# %%
# we need to compare to drawback and such

# %%
data[["returnsb&h", "strategy"]].sum().apply(np.exp) 
# what $1 investment will be
# Out:
# returnsb&h    14.536660
# strategy       1.013206
# dtype: float64

# %%
data[["returnsb&h", "strategy"]].std() * np.sqrt(252) 
# annual std
# Out:
# returnsb&h    0.393680
# strategy      0.393986
# dtype: float64

# %%
data.Close.plot(figsize = (12, 8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Long Bias Strategy Adjustment

# %%
data["position2"] = np.where(data["sma_s"] > data["sma_l"], 1, 0)

# %%
data["strategy2"] = data["returnsb&h"] * data.position2.shift(1)

# %%
data.dropna(inplace = True)

# %%
data[["returnsb&h", "strategy"]].sum()
# Out:
# returnsb&h    2.671089
# strategy      0.018705
# dtype: float64

# %%
# seeing the dollar investment 
data[["returnsb&h", "strategy"]].sum().apply(np.exp)
# Out:
# returnsb&h    14.455696
# strategy       1.018881
# dtype: float64

# %%
data[["returnsb&h", "strategy2"]].std() * np.sqrt(252)
# Out:
# returnsb&h    0.393749
# strategy2     0.272195
# dtype: float64

# %% [markdown]
# ## Strategy 2 is better than strategy 1 as we have reduced the risk

# %%
data[["strategy", "strategy2"]].std() * np.sqrt(252)
# Out:
# strategy     0.394055
# strategy2    0.272195
# dtype: float64

# %% [markdown]
# ## Creating own function

# %%
def test_strategy(stock, start, end, SMA):
    df = yf.download(stock, start = start, end = end)
    data = df.Close.to_frame()
    data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"] = data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"] = data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace = True)
    
    data["position"] = np.where(data["SMA_S"] > data["SMA_L"], 1, -1)
    data["strategy"] = data["returns"] * data.position.shift(1)
    data.dropna(inplace = True)
    ret = np.exp(data["strategy"].sum())
    std = data["strategy"].std() * np.sqrt(252)
    
    return ret, std

# %%
test_strategy("PLTR", "2020-10-23", "2023-08-27", (50, 200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# /Users/zekereyes/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (3.3455796347139293, 0.6877757824742929)

# %%
test_strategy("META", "2020-10-23", "2023-08-27", (50, 200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# /Users/zekereyes/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (2.822097252712969, 0.5466533946772407)

# %%
test_strategy("TSLA", "2020-10-23", "2023-08-27", (50, 200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# /Users/zekereyes/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (0.8040392893681912, 0.6146515306163525)

# %%
test_strategy("SPY", "2021-01-01", "2023-08-27", (50, 200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# /Users/zekereyes/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (0.9848936827036272, 0.20154588422210437)

# %% [markdown]
# ## Creating Class

# %%
class SMABacktester():
    def __init__(self, symbol, SMA_S, SMA_L, start, end):
        self.symbol = symbol
        self.SMA_S = SMA_S
        self.SMA_L = SMA_L
        self.start = start
        self.end = end
        self.results = None
        self.get_data() 
    
    def get_data(self):
        df = yf.download(self.symbol, start = self.start, end = self.end)
        data = df.Close.to_frame()
        data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"] = data.Close.rolling(self.SMA_S).mean()
        data["SMA_L"] = data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace = True)
        self.data2 = data
        
        return data
    
    def test_results(self):
        data = self.data2.copy().dropna()
        data["position"] = np.where(data["SMA_S"] > data["SMA_L"], 1, -1)
        data["strategy"] = data["returns"] * data.position.shift(1)
        data.dropna(inplace = True)
        data["returnsb&h"] = data["returns"].cumsum().apply(np.exp)
        data["returns_strategy"] = data["strategy"].cumsum().apply(np.exp)
        performance = data["returns_strategy"].iloc[-1]
        outperformance = performance - data["returnsb&h"].iloc[-1]
        self.results = data
        
        ret = np.exp(data["strategy"].sum())
        std = data["strategy"].std() * np.sqrt(252)

        return round(performance, 6), round(outperformance, 6)
    
    def plot_results(self):
        if self.results is None:
            print("Test function has not yet ran")
        else:
            title = "{} | SMA_S = {} | SMA_L{}".format(self.symbol, self.SMA_S, self.SMA_L)
            self.results[["returnsb&h", "returns_strategy"]].plot(title = title, figsize = (12, 8))

# %%
testing = SMABacktester("SNAP", 50, 100, "2022-01-01", "2023-08-26")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# /Users/zekereyes/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
testing.test_results()
# Out:
# (0.558791, -0.094457)

# %%
testing.plot_results()
